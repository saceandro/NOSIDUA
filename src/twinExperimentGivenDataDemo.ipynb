# %%
import twinExperimentGivenData

# %%
twinExperimentGivenData.main()
# Out:
# iter: 0
#       fun: 44.088455480219238
#  hess_inv: <7x7 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.0035956 ,  0.00282443,  0.00100185, -0.00202139,  0.00530331,
#         0.00055648,  0.00015058])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 58
#       nit: 51
#    status: 0
#   success: True
#         x: array([ 1.43098772,  4.78592118,  2.83295792, -3.17975449, -0.29395921,
#         8.08144432,  0.95417444])
# Smaller cost found.
#
# iter: 1
# Exception occurred in minimizer: overflow encountered in double_scalars
#
# iter: 2
# Exception occurred in minimizer: overflow encountered in double_scalars
#
# iter: 3
#       fun: 44.088453151082383
#  hess_inv: <7x7 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.00077569, -0.00027673,  0.00050839, -0.00050672, -0.00088426,
#        -0.00077317, -0.00358392])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 56
#       nit: 42
#    status: 0
# ...
